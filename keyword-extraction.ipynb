# %% [markdown]
# # PFE TC 2016-2017
# ## Keyword extraction
# Alexandre Batisse
#
# Nathanaël Leaute

# %% [markdown]
# # Description Générale
# ## Enoncé
# Kaggle est une plateforme organisant des compétitions de *Data Science*. Des entreprises peuvent ainsi proposer des sujets et récompenser les meilleurs solutions.
#
# Nous avons choisi pour notre PFE de répondre à un challenge proposé par *Facebook* en 2013 intitulé *Keywork Extraction*.
# L'objectif est de prédire les *tags* (mots-clés, sujets, etc.) de discussions questions/réponses des sites *Stack Exchange* en ne disposant que du titre du sujet et du corps de la question. Le jeu de données provient de différents sites stack exchange et mèle questions technique et non techniques.
#
# Le jeu de données comprend un jeu d'apprentissage (2.19 Go en .csv.zip), un jeu de test (725.10 Mo en .csv.zip) ainsi qu'un exemple de fichier de soumission (non utile à l'analyse).
#
# Train.csv contient quatre colonnes :
# - *Id* - Identifiant unique pour chaque question
# - *Title* - Titre de la question
# - *Body* - Corps de la question
# - *Tags* - Tags associés à la question (minuscules)
#
# Test.csv est construit de la même manière, à l'exception des *Tags* qui doivent être prédits.
#
# ## Métriques d'évaluation
# Les performances de notre solution sont évaluées par le *F1 score*. Ce score, qui est souvent utilisé dans les domaines du décisionnel et de la recherche d'informations, mesure l'exactitude de la solution par les statisques de *précision* et de *rappel*. Une bonne *précision* consiste à maximiser le nombre de résultats vrais positifs, tandis qu'un *rappel* important tend à diminuer le nombre de faux négatifs. Ces deux métriques sont complémentaires dans la constitution du score d'exactitude de la solution car une bonne *précision*, qui signifie un haut taux de réponses positives correctes, ne garantie pas l'exhaustivité de ces dernières.
#
# Soient *tp* le nombre de vrais positifs, *fp* le nombre de faux positifs et *fn* le nombre de faux négatifs. Nous obtenons les métriques suivantes :
#
# $$p=\frac{tp}{tp + fp}, r=\frac{tp}{tp + fn}$$
#
# Le *F1 score* est alors donné par :
# $$F1 = 2\frac{pr}{p + r}$$
#
# Pour chaque entrée du jeu de données de test, notre solution doit produire une entrée d'un fichier de réponse constituée de l'*id* de la question et d'une liste de *tags*. Le fichier de réponse doit avoir le format suivant :
#
# `Id,Tags
# 1,"c++ javaScript"
# 2,"php python mysql"
# 3,"django"`
#
# Nous soumettons ensuite ce fichier à la plateforme de challenge Kaggle qui nous renvoie par la suite notre score.

# %%
# Imports
import pandas as pd
import numpy as np
from psutil import virtual_memory
import tensorflow as tf

# %%
# Optimizing memory usage
mem = virtual_memory()
size = int(mem.total/1000000)
# Loading .csv.zip in dataframe
df = pd.read_csv('Train.zip', compression='zip',header=0,sep=',', quotechar='"', chunksize=size)

# %%
for chunk in df:
    print(chunk)
    break
# Out:
#         Id                                              Title  \
# 0        1  How to check if an uploaded file is an image w...
# 1        2  How can I prevent firefox from closing when I ...
# 2        3           R Error Invalid type (list) for variable
# 3        4      How do I replace special characters in a URL?
# 4        5               How to modify whois contact details?
# 5        6      setting proxy in active directory environment
# 6        7      How to draw barplot in this way with Coreplot
# 7        8             How to fetch an XML feed using asp.net
# 8        9            .NET library for generating javascript?
# 9       10  SQL Server : procedure call, inline concatenat...
# 10      11  How do commercial obfuscators achieve to crash...
# 11      12                     Crappy Random Number Generator
# 12      13                    Migrate from Mdaemon to postfix
# 13      14                Where can I find the LaTeX3 manual?
# 14      15  Can I stop windows 7 from fading windows on al...
# 15      16                      PHP framework URL conventions
# 16      17          What creates ".rds" temporary files in R?
# 17      18    WPF: multiple controls binding to same property
# 18      19    Play framework auto javascript and CSS minifier
# 19      20  Creating a repetitive node from a hash array w...
# 20      21  Are cancer recovery rates the same as they wer...
# 21      22                   Get all +ve number count in LINQ
# 22      23  TabNavigator contents width not equals with Ta...
# 23      24                            IIS File Size Reporting
# 24      25  C# Converting set flags in a variable of type ...
# 25      26                      Can i use printf in IO monad?
# 26      27               Is my understanding of MAKE correct?
# 27      28                              <p> instead of <br />
# 28      29                             GCC STL bound checking
# 29      30  SharePoint CAML query - query custom field usi...
# ...    ...                                                ...
# 6182  6183  What's the best way to do URL recognition with...
# 6183  6184                  Uploading Error with name of App?
# 6184  6185                            vim commands in Eclipse
# 6185  6186  Design practice for container class with multi...
# 6186  6187  Open Measurable Sets Containing All Rational N...
# 6187  6188   Java -> C++ TCP Socket does not send until close
# 6188  6189  What file extensions are blocked by default in...
# 6189  6190            How does QuickBooks handle IIF imports?
# 6190  6191  Windows 7: Is it possible to start a pinned it...
# 6191  6192  How to ensure 300+ pixels per inch for images ...
# 6192  6193  Create variable just a number from text/number...
# 6193  6194  Installing Mod-wsgi 3.3 for apache 2.2 and pyt...
# 6194  6195                   jquery get previous form element
# 6195  6196  ASP.NET ReportViewer's nav toolbar doesn't sho...
# 6196  6197  Why does accessing files in AppData (on Vista)...
# 6197  6198                 WPF - Parameters to DataTemplates?
# 6198  6199  cocos2d, CC_HONOR_PARENT_TRANSFORM_SCALE, how ...
# 6199  6200       thunderbird extension without xul (css only)
# 6200  6201  Catch MainLoop exceptions and displaying them ...
# 6201  6202                Sphinx search numbers with prefixes
# 6202  6203  SQL Server normalization tactic: varchar vs in...
# 6203  6204  Running Groovy script from Gradle using Groovy...
# 6204  6205                       Disable Cmd+Enter on iTerm 2
# 6205  6206               regex for parsing request parameters
# 6206  6207       Receiving Index Out of Range with NHibernate
# 6207  6208     Disable warning/error beep when changing focus
# 6208  6209  Maintaining a ServiceConnection in Android thr...
# 6209  6210  Was 19 the average age of a combat soldier in ...
# 6210  6211                    Macros for common abbreviations
# 6211  6212     Is the WCF REST Starter Kit dead in the water?
#
#                                                    Body  \
# 0     <p>I'd like to check if an uploaded file is an...
# 1     <p>In my favorite editor (vim), I regularly us...
# 2     <p>I am import matlab file and construct a dat...
# 3     <p>This is probably very simple, but I simply ...
# 4     <pre><code>function modify(.......)\n{\n  $mco...
# 5     <p>I am using a machine on which active direct...
# 6     <p>My image is cannot post so  the link is my ...
# 7     <p>I've decided to convert a Windows Phone 7 a...
# 8     <p>Do you know of a .NET library for generatin...
# 9     <p>I'm using SQL Server 2008 R2 and was wonder...
# 10    <p>Some commercial obfuscators <a href="http:/...
# 11    <p>This may sound like an odd question, but wh...
# 12    <p>how can I move Inbox/Sent/Draft from Mdaemo...
# 13    <p>Few month ago I saw a big pdf-manual of all...
# 14    <p>When you hit alt tab on windows 7 and stop ...
# 15    <p>A lot of frameworks use URL conventions lik...
# 16    <p>I'm running a server process in R that is r...
# 17    <p>Hello<br>\nI'm trying to change several con...
# 18    <p>Does anyone know a good play plugin that au...
# 19    <p>=) I need your kindly help to accomplish a ...
# 20    <p><strong>Related:</strong> <a href="http://s...
# 21    <p>I am using the following thing:</p>\n\n<pre...
# 22    <p>The content(Here is VBox) is not align with...
# 23    <p>How do I configure IIS to report File Size ...
# 24    <p>I came up with this piece of code that conv...
# 25    <p>The stopLoss function causes the following ...
# 26    <p>Taking the GNU make application as an examp...
# 27    <p>I've been wondering if I can use <code>&lt;...
# 28    <p>How to enable bound checking for <code>oper...
# 29    <p>I have a SharePoint document library with a...
# ...                                                 ...
# 6182  <p><em>Situation:</em>  </p>\n\n<p>I got one i...
# 6183  <p>I already filled the all details for app th...
# 6184  <p>I have been doing some java development lat...
# 6185  <p>I'm trying to design a class structure with...
# 6186  <p>So I am trying to figure out a proof for th...
# 6187  <p>I am facing another TCP Socket issue. \nI'v...
# 6188  <p>Some files are not served off of IIS becaus...
# 6189  <p>I've received a 'template' for an IIF file ...
# 6190  <p>I have Visual Studio 2012 and I pinned some...
# 6191  <p>I have a large Word 2007 document (a book) ...
# 6192  <p>I have a variable <code>var1</code>. In the...
# 6193  <p>I am attempting to install Mod-wsgi 3.3 on ...
# 6194  <p>This is an example code,</p>\n\n<pre><code>...
# 6195  <p>I am using ReportViewer in Visual Studio 20...
# 6196  <p>My application (vb.net) <strong>sometimes</...
# 6197  <p>I have a ListBox showing data about employe...
# 6198  <p>I want to add a sprite2 to sprite1, scale t...
# 6199  <p>what is required to create thunderbird exte...
# 6200  <p>I have a wxPython application that relies o...
# 6201  <p>How to query words with prefixes and suffix...
# 6202  <p>I'm just wondering what the optimal solutio...
# 6203  <p>I want to run a groovy command-line script ...
# 6204  <p>I'm using iTerm 2 on Mac, and whenever I pr...
# 6205  <p>I am looking for a single perl compatible r...
# 6206  <p>I'm hoping that someone can help me with th...
# 6207  <p>Whenever I change the focus from one textbo...
# 6208  <p>I have an Activity that holds a ServiceConn...
# 6209  <p>The anti-war song <a href="http://www.youtu...
# 6210  <p>Common abbreviations are surprisingly trick...
# 6211  <p>We are looking at switching from using WCF ...
#
#                                                    Tags
# 0     php image-processing file-upload upload mime-t...
# 1                                               firefox
# 2                             r matlab machine-learning
# 3                                       c# url encoding
# 4                             php api file-get-contents
# 5                         proxy active-directory jmeter
# 6                                             core-plot
# 7                            c# asp.net windows-phone-7
# 8                       .net javascript code-generation
# 9              sql variables parameters procedure calls
# 10                           .net obfuscation reflector
# 11                   algorithm language-agnostic random
# 12                            postfix migration mdaemon
# 13                           documentation latex3 expl3
# 14                                            windows-7
# 15                          php url-routing conventions
# 16                                    r temporary-files
# 17                                          wpf binding
# 18      javascript code-generation playframework minify
# 19    php xml hash multidimensional-array simplexml-...
# 20                    medical-science cancer healthcare
# 21                                         c# .net linq
# 22                            actionscript-3 flex flex3
# 23                                                  iis
# 24                           c# linq string enumeration
# 25                                              haskell
# 26                           visual-studio makefile gnu
# 27                            html semantic line-breaks
# 28                           c++ gcc stl bounds-checker
# 29                        sharepoint caml custom-fields
# ...                                                 ...
# 6182                            javascript jquery regex
# 6183                           iphone objective-c xcode
# 6184                                        eclipse vim
# 6185                               c# class collections
# 6186                       real-analysis measure-theory
# 6187                        java c++ sockets tcp stream
# 6188                       asp.net .net asp.net-mvc iis
# 6189                                  import quickbooks
# 6190        windows windows-7 uac administrator taskbar
# 6191    windows-xp pdf microsoft-word-2007 print-to-pdf
# 6192                                         c# asp.net
# 6193                            apache2 python mod-wsgi
# 6194                                   jquery forms dom
# 6195  asp.net visual-studio-2010 rdlc report-viewer2010
# 6196                               vb.net windows-vista
# 6197                                   wpf datatemplate
# 6198                                objective-c cocos2d
# 6199                              css thunderbird-addon
# 6200       python exception-handling wxpython wxwidgets
# 6201                                             sphinx
# 6202  sql sql-server database-design optimization no...
# 6203                                      groovy gradle
# 6204                                         osx iterm2
# 6205                                         regex pcre
# 6206                      nhibernate nhibernate-mapping
# 6207                                                 c#
# 6208  android activity screen-orientation servicecon...
# 6209                          history united-states war
# 6210                     macros spacing acronyms xspace
# 6211                                      .net wcf rest
#
# [6212 rows x 4 columns]
